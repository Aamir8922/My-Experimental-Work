# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the BiLSTM model
def build_BiLSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
bilstm_model = build_BiLSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = bilstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = bilstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# C:\Users\Younas\AppData\Local\Temp\ipykernel_18188\2651253809.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_18188\2651253809.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 134/134 [==============================] - 104s 731ms/step - loss: 0.4557 - accuracy: 0.7778 - val_loss: 0.3952 - val_accuracy: 0.8623
# Epoch 2/10
# 134/134 [==============================] - 100s 750ms/step - loss: 0.2759 - accuracy: 0.8868 - val_loss: 0.2764 - val_accuracy: 0.9247
# Epoch 3/10
# 134/134 [==============================] - 108s 803ms/step - loss: 0.2250 - accuracy: 0.9128 - val_loss: 0.2301 - val_accuracy: 0.9523
# Epoch 4/10
# 134/134 [==============================] - 112s 839ms/step - loss: 0.1798 - accuracy: 0.9341 - val_loss: 0.2144 - val_accuracy: 0.9508
# Epoch 5/10
# 134/134 [==============================] - 111s 830ms/step - loss: 0.1515 - accuracy: 0.9462 - val_loss: 0.1150 - val_accuracy: 0.9877
# Epoch 6/10
# 134/134 [==============================] - 107s 801ms/step - loss: 0.1278 - accuracy: 0.9553 - val_loss: 0.1021 - val_accuracy: 0.9877
# Epoch 7/10
# 134/134 [==============================] - 110s 823ms/step - loss: 0.1030 - accuracy: 0.9671 - val_loss: 0.0739 - val_accuracy: 0.9973
# Epoch 8/10
# 134/134 [==============================] - 112s 836ms/step - loss: 0.0919 - accuracy: 0.9702 - val_loss: 0.0756 - val_accuracy: 0.9889
# 58/58 [==============================] - 2s 25ms/step
# Epoch 1/10
# 134/134 [==============================] - 110s 823ms/step - loss: 0.6020 - accuracy: 0.7137 - val_loss: 0.6648 - val_accuracy: 0.6523
# Epoch 2/10
# 134/134 [==============================] - 105s 781ms/step - loss: 0.3512 - accuracy: 0.8535 - val_loss: 0.3217 - val_accuracy: 0.8851
# Epoch 3/10
# 134/134 [==============================] - 104s 777ms/step - loss: 0.2509 - accuracy: 0.9054 - val_loss: 0.2317 - val_accuracy: 0.9448
# Epoch 4/10
# 134/134 [==============================] - 104s 779ms/step - loss: 0.1884 - accuracy: 0.9305 - val_loss: 0.1709 - val_accuracy: 0.9685
# Epoch 5/10
# 134/134 [==============================] - 103s 771ms/step - loss: 0.1488 - accuracy: 0.9488 - val_loss: 0.1392 - val_accuracy: 0.9715
# Epoch 6/10
# 134/134 [==============================] - 104s 780ms/step - loss: 0.1215 - accuracy: 0.9594 - val_loss: 0.1626 - val_accuracy: 0.9694
# 58/58 [==============================] - 2s 29ms/step
# Epoch 1/10
# 134/134 [==============================] - 106s 790ms/step - loss: 0.5138 - accuracy: 0.7705 - val_loss: 0.5910 - val_accuracy: 0.7246
# Epoch 2/10
# 134/134 [==============================] - 104s 780ms/step - loss: 0.2812 - accuracy: 0.8879 - val_loss: 0.2604 - val_accuracy: 0.9337
# Epoch 3/10
# 134/134 [==============================] - 105s 785ms/step - loss: 0.1798 - accuracy: 0.9364 - val_loss: 0.1189 - val_accuracy: 0.9814
# Epoch 4/10
# 134/134 [==============================] - 105s 786ms/step - loss: 0.1368 - accuracy: 0.9542 - val_loss: 0.0984 - val_accuracy: 0.9898
# Epoch 5/10
# 134/134 [==============================] - 119s 888ms/step - loss: 0.1128 - accuracy: 0.9636 - val_loss: 0.0642 - val_accuracy: 0.9943
# Epoch 6/10
# 134/134 [==============================] - 153s 1s/step - loss: 0.0958 - accuracy: 0.9698 - val_loss: 0.0634 - val_accuracy: 0.9961
# Epoch 7/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.0805 - accuracy: 0.9755 - val_loss: 0.0692 - val_accuracy: 0.9928
# 58/58 [==============================] - 2s 38ms/step
# Epoch 1/10
# 134/134 [==============================] - 249s 2s/step - loss: 0.5136 - accuracy: 0.7748 - val_loss: 0.3599 - val_accuracy: 0.8635
# Epoch 2/10
# 134/134 [==============================] - 348s 3s/step - loss: 0.2779 - accuracy: 0.8872 - val_loss: 0.3101 - val_accuracy: 0.9025
# Epoch 3/10
# 134/134 [==============================] - 371s 3s/step - loss: 0.1957 - accuracy: 0.9257 - val_loss: 0.1738 - val_accuracy: 0.9664
# Epoch 4/10
# 134/134 [==============================] - 365s 3s/step - loss: 0.1448 - accuracy: 0.9485 - val_loss: 0.1477 - val_accuracy: 0.9721
# Epoch 5/10
# 134/134 [==============================] - 371s 3s/step - loss: 0.1165 - accuracy: 0.9598 - val_loss: 0.0739 - val_accuracy: 0.9931
# Epoch 6/10
# 134/134 [==============================] - 372s 3s/step - loss: 0.0923 - accuracy: 0.9692 - val_loss: 0.0612 - val_accuracy: 0.9943
# Epoch 7/10
# 134/134 [==============================] - 329s 2s/step - loss: 0.0785 - accuracy: 0.9753 - val_loss: 0.0521 - val_accuracy: 0.9952
# Epoch 8/10
# 134/134 [==============================] - 261s 2s/step - loss: 0.0710 - accuracy: 0.9784 - val_loss: 0.0439 - val_accuracy: 0.9961
# Epoch 9/10
# 134/134 [==============================] - 258s 2s/step - loss: 0.0609 - accuracy: 0.9822 - val_loss: 0.0592 - val_accuracy: 0.9967
# 58/58 [==============================] - 5s 78ms/step
# Epoch 1/10
# 134/134 [==============================] - 170s 1s/step - loss: 0.5649 - accuracy: 0.7437 - val_loss: 0.6361 - val_accuracy: 0.6727
# Epoch 2/10
# 134/134 [==============================] - 144s 1s/step - loss: 0.3147 - accuracy: 0.8646 - val_loss: 0.2889 - val_accuracy: 0.8917
# Epoch 3/10
# 134/134 [==============================] - 144s 1s/step - loss: 0.2049 - accuracy: 0.9201 - val_loss: 0.1677 - val_accuracy: 0.9646
# Epoch 4/10
# 134/134 [==============================] - 146s 1s/step - loss: 0.1428 - accuracy: 0.9496 - val_loss: 0.0813 - val_accuracy: 0.9880
# Epoch 5/10
# 134/134 [==============================] - 146s 1s/step - loss: 0.1071 - accuracy: 0.9629 - val_loss: 0.0653 - val_accuracy: 0.9922
# Epoch 6/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.0859 - accuracy: 0.9735 - val_loss: 0.0547 - val_accuracy: 0.9910
# Epoch 7/10
# 134/134 [==============================] - 145s 1s/step - loss: 0.0779 - accuracy: 0.9758 - val_loss: 0.0679 - val_accuracy: 0.9823
# 58/58 [==============================] - 2s 35ms/step
# Epoch 1/10
# 134/134 [==============================] - 142s 1s/step - loss: 0.5200 - accuracy: 0.7780 - val_loss: 0.3531 - val_accuracy: 0.8593
# Epoch 2/10
# 134/134 [==============================] - 147s 1s/step - loss: 0.2620 - accuracy: 0.8945 - val_loss: 0.2256 - val_accuracy: 0.9397
# Epoch 3/10
# 134/134 [==============================] - 144s 1s/step - loss: 0.1772 - accuracy: 0.9368 - val_loss: 0.1901 - val_accuracy: 0.9541
# Epoch 4/10
# 134/134 [==============================] - 146s 1s/step - loss: 0.1295 - accuracy: 0.9574 - val_loss: 0.0790 - val_accuracy: 0.9916
# Epoch 5/10
# 134/134 [==============================] - 147s 1s/step - loss: 0.1067 - accuracy: 0.9645 - val_loss: 0.0765 - val_accuracy: 0.9934
# Epoch 6/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.0858 - accuracy: 0.9729 - val_loss: 0.0668 - val_accuracy: 0.9928
# Epoch 7/10
# 134/134 [==============================] - 147s 1s/step - loss: 0.0769 - accuracy: 0.9770 - val_loss: 0.0389 - val_accuracy: 0.9943
# Epoch 8/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.0634 - accuracy: 0.9809 - val_loss: 0.0383 - val_accuracy: 0.9934
# Epoch 9/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.0578 - accuracy: 0.9833 - val_loss: 0.0222 - val_accuracy: 0.9961
# Epoch 10/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.0518 - accuracy: 0.9853 - val_loss: 0.0206 - val_accuracy: 0.9964
# 58/58 [==============================] - 2s 37ms/step
# Epoch 1/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.5460 - accuracy: 0.7726 - val_loss: 0.4623 - val_accuracy: 0.8041
# Epoch 2/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.2845 - accuracy: 0.8822 - val_loss: 0.2888 - val_accuracy: 0.8953
# Epoch 3/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.1872 - accuracy: 0.9296 - val_loss: 0.1340 - val_accuracy: 0.9736
# Epoch 4/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.1353 - accuracy: 0.9543 - val_loss: 0.0909 - val_accuracy: 0.9895
# Epoch 5/10
# 134/134 [==============================] - 146s 1s/step - loss: 0.1061 - accuracy: 0.9659 - val_loss: 0.0701 - val_accuracy: 0.9916
# Epoch 6/10
# 134/134 [==============================] - 150s 1s/step - loss: 0.0841 - accuracy: 0.9736 - val_loss: 0.0382 - val_accuracy: 0.9988
# Epoch 7/10
# 134/134 [==============================] - 147s 1s/step - loss: 0.0728 - accuracy: 0.9779 - val_loss: 0.0316 - val_accuracy: 0.9949
# Epoch 8/10
# 134/134 [==============================] - 152s 1s/step - loss: 0.0627 - accuracy: 0.9812 - val_loss: 0.0402 - val_accuracy: 0.9940
# 58/58 [==============================] - 2s 35ms/step
# Epoch 1/10
# 134/134 [==============================] - 148s 1s/step - loss: 0.4974 - accuracy: 0.7962 - val_loss: 0.3673 - val_accuracy: 0.8479
# Epoch 2/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.2390 - accuracy: 0.9028 - val_loss: 0.1965 - val_accuracy: 0.9529
# Epoch 3/10
# 134/134 [==============================] - 150s 1s/step - loss: 0.1600 - accuracy: 0.9416 - val_loss: 0.1175 - val_accuracy: 0.9796
# Epoch 4/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.1185 - accuracy: 0.9595 - val_loss: 0.0540 - val_accuracy: 0.9949
# Epoch 5/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.1004 - accuracy: 0.9674 - val_loss: 0.0494 - val_accuracy: 0.9934
# Epoch 6/10
# 134/134 [==============================] - 152s 1s/step - loss: 0.0760 - accuracy: 0.9776 - val_loss: 0.0291 - val_accuracy: 0.9988
# Epoch 7/10
# 134/134 [==============================] - 153s 1s/step - loss: 0.0674 - accuracy: 0.9803 - val_loss: 0.0427 - val_accuracy: 0.9958
# 58/58 [==============================] - 2s 36ms/step
# Epoch 1/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.4988 - accuracy: 0.7892 - val_loss: 0.4094 - val_accuracy: 0.8254
# Epoch 2/10
# 134/134 [==============================] - 153s 1s/step - loss: 0.2413 - accuracy: 0.9014 - val_loss: 0.1528 - val_accuracy: 0.9637
# Epoch 3/10
# 134/134 [==============================] - 152s 1s/step - loss: 0.1655 - accuracy: 0.9402 - val_loss: 0.0868 - val_accuracy: 0.9898
# Epoch 4/10
# 134/134 [==============================] - 154s 1s/step - loss: 0.1197 - accuracy: 0.9581 - val_loss: 0.0976 - val_accuracy: 0.9916
# 58/58 [==============================] - 2s 37ms/step
# Epoch 1/10
# 134/134 [==============================] - 150s 1s/step - loss: 0.4850 - accuracy: 0.7927 - val_loss: 0.4623 - val_accuracy: 0.7930
# Epoch 2/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.2578 - accuracy: 0.8953 - val_loss: 0.1848 - val_accuracy: 0.9640
# Epoch 3/10
# 134/134 [==============================] - 150s 1s/step - loss: 0.1739 - accuracy: 0.9359 - val_loss: 0.1339 - val_accuracy: 0.9820
# Epoch 4/10
# 134/134 [==============================] - 153s 1s/step - loss: 0.1279 - accuracy: 0.9546 - val_loss: 0.0746 - val_accuracy: 0.9889
# Epoch 5/10
# 134/134 [==============================] - 149s 1s/step - loss: 0.0972 - accuracy: 0.9687 - val_loss: 0.0416 - val_accuracy: 0.9952
# Epoch 6/10
# 134/134 [==============================] - 151s 1s/step - loss: 0.0800 - accuracy: 0.9749 - val_loss: 0.0424 - val_accuracy: 0.9934
# 58/58 [==============================] - 2s 39ms/step
# Avg accuracy : 0.9655443383005862
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      9258
#            1       0.99      0.94      0.96      9258
#
#     accuracy                           0.97     18516
#    macro avg       0.97      0.97      0.97     18516
# weighted avg       0.97      0.97      0.97     18516

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply undersampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the BiLSTM model
def build_BiLSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
bilstm_model = build_BiLSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = bilstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = bilstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# C:\Users\Younas\AppData\Local\Temp\ipykernel_3796\3039477477.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_3796\3039477477.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 11/11 [==============================] - 40s 944ms/step - loss: 0.6699 - accuracy: 0.6201 - val_loss: 1.0335 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 9s 830ms/step - loss: 0.6428 - accuracy: 0.6238 - val_loss: 0.8816 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 10s 902ms/step - loss: 0.5842 - accuracy: 0.6857 - val_loss: 1.0194 - val_accuracy: 0.2247
# 5/5 [==============================] - 1s 41ms/step
# Epoch 1/10
# 11/11 [==============================] - 11s 965ms/step - loss: 0.6124 - accuracy: 0.6670 - val_loss: 0.8915 - val_accuracy: 0.3670
# Epoch 2/10
# 11/11 [==============================] - 11s 959ms/step - loss: 0.5118 - accuracy: 0.7336 - val_loss: 0.7239 - val_accuracy: 0.5805
# Epoch 3/10
# 11/11 [==============================] - 13s 1s/step - loss: 0.4290 - accuracy: 0.8114 - val_loss: 0.8653 - val_accuracy: 0.5431
# 5/5 [==============================] - 0s 68ms/step
# Epoch 1/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.6139 - accuracy: 0.6785 - val_loss: 0.7917 - val_accuracy: 0.4794
# Epoch 2/10
# 11/11 [==============================] - 14s 1s/step - loss: 0.5233 - accuracy: 0.7413 - val_loss: 0.7071 - val_accuracy: 0.5618
# Epoch 3/10
# 11/11 [==============================] - 14s 1s/step - loss: 0.4619 - accuracy: 0.7985 - val_loss: 0.8563 - val_accuracy: 0.4869
# 5/5 [==============================] - 0s 55ms/step
# Epoch 1/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.6219 - accuracy: 0.6532 - val_loss: 0.8578 - val_accuracy: 0.4307
# Epoch 2/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.5579 - accuracy: 0.7113 - val_loss: 0.9603 - val_accuracy: 0.3933
# 5/5 [==============================] - 0s 60ms/step
# Epoch 1/10
# 11/11 [==============================] - 16s 1s/step - loss: 0.5752 - accuracy: 0.6973 - val_loss: 0.8172 - val_accuracy: 0.5243
# Epoch 2/10
# 11/11 [==============================] - 14s 1s/step - loss: 0.5194 - accuracy: 0.7441 - val_loss: 0.7552 - val_accuracy: 0.5993
# Epoch 3/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.4496 - accuracy: 0.7966 - val_loss: 0.8746 - val_accuracy: 0.5918
# 5/5 [==============================] - 1s 65ms/step
# Epoch 1/10
# 11/11 [==============================] - 19s 2s/step - loss: 0.5607 - accuracy: 0.7170 - val_loss: 0.9386 - val_accuracy: 0.4869
# Epoch 2/10
# 11/11 [==============================] - 17s 2s/step - loss: 0.4953 - accuracy: 0.7685 - val_loss: 0.8779 - val_accuracy: 0.5468
# Epoch 3/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.4451 - accuracy: 0.8116 - val_loss: 0.8586 - val_accuracy: 0.6180
# Epoch 4/10
# 11/11 [==============================] - 18s 2s/step - loss: 0.4052 - accuracy: 0.8238 - val_loss: 0.9397 - val_accuracy: 0.5843
# 5/5 [==============================] - 1s 79ms/step
# Epoch 1/10
# 11/11 [==============================] - 19s 2s/step - loss: 0.5969 - accuracy: 0.6870 - val_loss: 0.8179 - val_accuracy: 0.5805
# Epoch 2/10
# 11/11 [==============================] - 18s 2s/step - loss: 0.5221 - accuracy: 0.7395 - val_loss: 0.9362 - val_accuracy: 0.4869
# 5/5 [==============================] - 0s 62ms/step
# Epoch 1/10
# 11/11 [==============================] - 14s 1s/step - loss: 0.5719 - accuracy: 0.6832 - val_loss: 0.7767 - val_accuracy: 0.5730
# Epoch 2/10
# 11/11 [==============================] - 16s 1s/step - loss: 0.5228 - accuracy: 0.7263 - val_loss: 0.8633 - val_accuracy: 0.5431
# 5/5 [==============================] - 0s 69ms/step
# Epoch 1/10
# 11/11 [==============================] - 16s 1s/step - loss: 0.5742 - accuracy: 0.6982 - val_loss: 0.7762 - val_accuracy: 0.5918
# Epoch 2/10
# 11/11 [==============================] - 16s 1s/step - loss: 0.5290 - accuracy: 0.7282 - val_loss: 0.9315 - val_accuracy: 0.5243
# 5/5 [==============================] - 0s 65ms/step
# Epoch 1/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.5619 - accuracy: 0.6954 - val_loss: 0.8281 - val_accuracy: 0.5655
# Epoch 2/10
# 11/11 [==============================] - 15s 1s/step - loss: 0.5191 - accuracy: 0.7310 - val_loss: 0.8682 - val_accuracy: 0.5468
# 5/5 [==============================] - 0s 60ms/step
# Avg accuracy : 0.675453473607836
#               precision    recall  f1-score   support
#
#            0       0.63      0.86      0.73       741
#            1       0.78      0.49      0.60       741
#
#     accuracy                           0.68      1482
#    macro avg       0.70      0.68      0.66      1482
# weighted avg       0.70      0.68      0.66      1482
