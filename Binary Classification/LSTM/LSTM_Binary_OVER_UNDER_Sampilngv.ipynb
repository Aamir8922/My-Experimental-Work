# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = lstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = lstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(12, 6))
    
    # Plot for model accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    
    # Plot for model loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper left')
    
    # Save the figure before showing
    plt.savefig('training_validation_loss_accuracy_lstm.png', dpi=300)
    
    plt.show()


plot_history(history)

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
import numpy as np

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))  # Optional: Define the figure size
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('confusion_matrix_lstm.png', dpi=300)  # Save the plot with 300 DPI
    plt.show()

# Example usage:
# plot_confusion_matrix(y_true, y_pred, classes=['Class 1', 'Class 2'], title='Confusion matrix')


from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('ROC_curve.png', dpi=300)  # Save the plot with 300 DPI
    plt.show()

# Example usage:
# plot_roc_curve(y_true, y_pred_proba)


# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# Dataset loaded.
# NLTK data downloaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_21020\3014966468.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 134/134 [==============================] - 36s 242ms/step - loss: 0.4614 - accuracy: 0.7731 - val_loss: 0.4630 - val_accuracy: 0.8017
# Epoch 2/10
# 134/134 [==============================] - 33s 243ms/step - loss: 0.2853 - accuracy: 0.8829 - val_loss: 0.2808 - val_accuracy: 0.9166
# Epoch 3/10
# 134/134 [==============================] - 34s 252ms/step - loss: 0.2234 - accuracy: 0.9145 - val_loss: 0.2331 - val_accuracy: 0.9520
# Epoch 4/10
# 134/134 [==============================] - 34s 257ms/step - loss: 0.1777 - accuracy: 0.9367 - val_loss: 0.1678 - val_accuracy: 0.9847
# Epoch 5/10
# 134/134 [==============================] - 34s 253ms/step - loss: 0.1463 - accuracy: 0.9507 - val_loss: 0.1406 - val_accuracy: 0.9739
# Epoch 6/10
# 134/134 [==============================] - 34s 251ms/step - loss: 0.1243 - accuracy: 0.9584 - val_loss: 0.0878 - val_accuracy: 0.9958
# Epoch 7/10
# 134/134 [==============================] - 34s 255ms/step - loss: 0.1088 - accuracy: 0.9639 - val_loss: 0.1041 - val_accuracy: 0.9817
# 58/58 [==============================] - 1s 18ms/step
# Epoch 1/10
# 134/134 [==============================] - 32s 240ms/step - loss: 0.5716 - accuracy: 0.7334 - val_loss: 0.5405 - val_accuracy: 0.7498
# Epoch 2/10
# 134/134 [==============================] - 32s 240ms/step - loss: 0.3333 - accuracy: 0.8618 - val_loss: 0.3161 - val_accuracy: 0.8836
# Epoch 3/10
# 134/134 [==============================] - 32s 240ms/step - loss: 0.2372 - accuracy: 0.9075 - val_loss: 0.2218 - val_accuracy: 0.9481
# Epoch 4/10
# 134/134 [==============================] - 32s 240ms/step - loss: 0.1801 - accuracy: 0.9352 - val_loss: 0.1771 - val_accuracy: 0.9772
# Epoch 5/10
# 134/134 [==============================] - 32s 239ms/step - loss: 0.1438 - accuracy: 0.9488 - val_loss: 0.1182 - val_accuracy: 0.9838
# Epoch 6/10
# 134/134 [==============================] - 33s 244ms/step - loss: 0.1176 - accuracy: 0.9585 - val_loss: 0.0716 - val_accuracy: 0.9892
# Epoch 7/10
# 134/134 [==============================] - 32s 242ms/step - loss: 0.0996 - accuracy: 0.9676 - val_loss: 0.0865 - val_accuracy: 0.9811
# 58/58 [==============================] - 1s 19ms/step
# Epoch 1/10
# 134/134 [==============================] - 32s 242ms/step - loss: 0.5458 - accuracy: 0.7522 - val_loss: 0.4324 - val_accuracy: 0.8248
# Epoch 2/10
# 134/134 [==============================] - 33s 243ms/step - loss: 0.3030 - accuracy: 0.8763 - val_loss: 0.2126 - val_accuracy: 0.9475
# Epoch 3/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.1966 - accuracy: 0.9275 - val_loss: 0.2053 - val_accuracy: 0.9451
# Epoch 4/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1440 - accuracy: 0.9502 - val_loss: 0.0820 - val_accuracy: 0.9904
# Epoch 5/10
# 134/134 [==============================] - 33s 243ms/step - loss: 0.1132 - accuracy: 0.9628 - val_loss: 0.0804 - val_accuracy: 0.9862
# Epoch 6/10
# 134/134 [==============================] - 33s 245ms/step - loss: 0.0959 - accuracy: 0.9689 - val_loss: 0.0645 - val_accuracy: 0.9865
# Epoch 7/10
# 134/134 [==============================] - 34s 254ms/step - loss: 0.0807 - accuracy: 0.9753 - val_loss: 0.0467 - val_accuracy: 0.9961
# Epoch 8/10
# 134/134 [==============================] - 34s 253ms/step - loss: 0.0747 - accuracy: 0.9759 - val_loss: 0.0416 - val_accuracy: 0.9985
# Epoch 9/10
# 134/134 [==============================] - 35s 263ms/step - loss: 0.0586 - accuracy: 0.9817 - val_loss: 0.0364 - val_accuracy: 0.9928
# Epoch 10/10
# 134/134 [==============================] - 35s 257ms/step - loss: 0.0537 - accuracy: 0.9835 - val_loss: 0.0306 - val_accuracy: 0.9967
# 58/58 [==============================] - 1s 22ms/step
# Epoch 1/10
# 134/134 [==============================] - 34s 255ms/step - loss: 0.5211 - accuracy: 0.7680 - val_loss: 0.4352 - val_accuracy: 0.8305
# Epoch 2/10
# 134/134 [==============================] - 34s 256ms/step - loss: 0.2745 - accuracy: 0.8886 - val_loss: 0.2104 - val_accuracy: 0.9538
# Epoch 3/10
# 134/134 [==============================] - 32s 238ms/step - loss: 0.1895 - accuracy: 0.9303 - val_loss: 0.1347 - val_accuracy: 0.9754
# Epoch 4/10
# 134/134 [==============================] - 32s 238ms/step - loss: 0.1400 - accuracy: 0.9500 - val_loss: 0.0792 - val_accuracy: 0.9922
# Epoch 5/10
# 134/134 [==============================] - 33s 247ms/step - loss: 0.1115 - accuracy: 0.9616 - val_loss: 0.0726 - val_accuracy: 0.9949
# Epoch 6/10
# 134/134 [==============================] - 32s 241ms/step - loss: 0.0971 - accuracy: 0.9670 - val_loss: 0.0463 - val_accuracy: 0.9982
# Epoch 7/10
# 134/134 [==============================] - 36s 272ms/step - loss: 0.0776 - accuracy: 0.9762 - val_loss: 0.0340 - val_accuracy: 0.9988
# Epoch 8/10
# 134/134 [==============================] - 34s 253ms/step - loss: 0.0674 - accuracy: 0.9782 - val_loss: 0.0505 - val_accuracy: 0.9961
# 58/58 [==============================] - 1s 20ms/step
# Epoch 1/10
# 134/134 [==============================] - 36s 271ms/step - loss: 0.5959 - accuracy: 0.7232 - val_loss: 0.5892 - val_accuracy: 0.6985
# Epoch 2/10
# 134/134 [==============================] - 34s 250ms/step - loss: 0.3367 - accuracy: 0.8514 - val_loss: 0.4105 - val_accuracy: 0.8284
# Epoch 3/10
# 134/134 [==============================] - 34s 254ms/step - loss: 0.2232 - accuracy: 0.9124 - val_loss: 0.2053 - val_accuracy: 0.9418
# Epoch 4/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.1553 - accuracy: 0.9444 - val_loss: 0.1406 - val_accuracy: 0.9757
# Epoch 5/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.1168 - accuracy: 0.9610 - val_loss: 0.0483 - val_accuracy: 0.9955
# Epoch 6/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.0891 - accuracy: 0.9717 - val_loss: 0.0683 - val_accuracy: 0.9898
# 58/58 [==============================] - 1s 18ms/step
# Epoch 1/10
# 134/134 [==============================] - 33s 243ms/step - loss: 0.5341 - accuracy: 0.7613 - val_loss: 0.4713 - val_accuracy: 0.7975
# Epoch 2/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.2900 - accuracy: 0.8779 - val_loss: 0.2142 - val_accuracy: 0.9454
# Epoch 3/10
# 134/134 [==============================] - 33s 244ms/step - loss: 0.1959 - accuracy: 0.9253 - val_loss: 0.1461 - val_accuracy: 0.9709
# Epoch 4/10
# 134/134 [==============================] - 32s 242ms/step - loss: 0.1456 - accuracy: 0.9491 - val_loss: 0.1170 - val_accuracy: 0.9820
# Epoch 5/10
# 134/134 [==============================] - 32s 242ms/step - loss: 0.1133 - accuracy: 0.9622 - val_loss: 0.1015 - val_accuracy: 0.9871
# Epoch 6/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.0912 - accuracy: 0.9730 - val_loss: 0.0426 - val_accuracy: 0.9955
# Epoch 7/10
# 134/134 [==============================] - 32s 241ms/step - loss: 0.0783 - accuracy: 0.9751 - val_loss: 0.0629 - val_accuracy: 0.9904
# 58/58 [==============================] - 1s 19ms/step
# Epoch 1/10
# 134/134 [==============================] - 32s 239ms/step - loss: 0.5523 - accuracy: 0.7576 - val_loss: 0.4402 - val_accuracy: 0.8203
# Epoch 2/10
# 134/134 [==============================] - 33s 245ms/step - loss: 0.2921 - accuracy: 0.8773 - val_loss: 0.3067 - val_accuracy: 0.8932
# Epoch 3/10
# 134/134 [==============================] - 33s 244ms/step - loss: 0.1960 - accuracy: 0.9248 - val_loss: 0.1746 - val_accuracy: 0.9559
# Epoch 4/10
# 134/134 [==============================] - 33s 249ms/step - loss: 0.1406 - accuracy: 0.9502 - val_loss: 0.0826 - val_accuracy: 0.9913
# Epoch 5/10
# 134/134 [==============================] - 34s 251ms/step - loss: 0.1082 - accuracy: 0.9636 - val_loss: 0.0776 - val_accuracy: 0.9904
# Epoch 6/10
# 134/134 [==============================] - 33s 247ms/step - loss: 0.0882 - accuracy: 0.9719 - val_loss: 0.0314 - val_accuracy: 0.9982
# Epoch 7/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.0735 - accuracy: 0.9770 - val_loss: 0.0380 - val_accuracy: 0.9955
# 58/58 [==============================] - 1s 19ms/step
# Epoch 1/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.5109 - accuracy: 0.7789 - val_loss: 0.3961 - val_accuracy: 0.8365
# Epoch 2/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.2494 - accuracy: 0.8991 - val_loss: 0.2161 - val_accuracy: 0.9559
# Epoch 3/10
# 134/134 [==============================] - 33s 244ms/step - loss: 0.1660 - accuracy: 0.9403 - val_loss: 0.1068 - val_accuracy: 0.9889
# Epoch 4/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.1185 - accuracy: 0.9612 - val_loss: 0.0720 - val_accuracy: 0.9961
# Epoch 5/10
# 134/134 [==============================] - 34s 250ms/step - loss: 0.0936 - accuracy: 0.9689 - val_loss: 0.0845 - val_accuracy: 0.9910
# 58/58 [==============================] - 1s 19ms/step
# Epoch 1/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.4948 - accuracy: 0.7868 - val_loss: 0.3212 - val_accuracy: 0.8851
# Epoch 2/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.2505 - accuracy: 0.8964 - val_loss: 0.1982 - val_accuracy: 0.9484
# Epoch 3/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.1688 - accuracy: 0.9364 - val_loss: 0.1102 - val_accuracy: 0.9868
# Epoch 4/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.1215 - accuracy: 0.9601 - val_loss: 0.0708 - val_accuracy: 0.9946
# Epoch 5/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.0927 - accuracy: 0.9707 - val_loss: 0.0599 - val_accuracy: 0.9925
# Epoch 6/10
# 134/134 [==============================] - 34s 256ms/step - loss: 0.0798 - accuracy: 0.9756 - val_loss: 0.0400 - val_accuracy: 0.9964
# Epoch 7/10
# 134/134 [==============================] - 33s 250ms/step - loss: 0.0689 - accuracy: 0.9787 - val_loss: 0.0209 - val_accuracy: 0.9985
# Epoch 8/10
# 134/134 [==============================] - 33s 247ms/step - loss: 0.0576 - accuracy: 0.9843 - val_loss: 0.0271 - val_accuracy: 0.9946
# 58/58 [==============================] - 1s 20ms/step
# Epoch 1/10
# 134/134 [==============================] - 33s 248ms/step - loss: 0.5038 - accuracy: 0.7934 - val_loss: 0.3871 - val_accuracy: 0.8506
# Epoch 2/10
# 134/134 [==============================] - 34s 251ms/step - loss: 0.2353 - accuracy: 0.9053 - val_loss: 0.1549 - val_accuracy: 0.9829
# Epoch 3/10
# 134/134 [==============================] - 33s 245ms/step - loss: 0.1547 - accuracy: 0.9443 - val_loss: 0.1268 - val_accuracy: 0.9892
# Epoch 4/10
# 134/134 [==============================] - 33s 245ms/step - loss: 0.1114 - accuracy: 0.9616 - val_loss: 0.0839 - val_accuracy: 0.9862
# Epoch 5/10
# 134/134 [==============================] - 33s 243ms/step - loss: 0.0830 - accuracy: 0.9737 - val_loss: 0.0415 - val_accuracy: 0.9961
# Epoch 6/10
# 134/134 [==============================] - 33s 245ms/step - loss: 0.0681 - accuracy: 0.9789 - val_loss: 0.0345 - val_accuracy: 0.9970
# Epoch 7/10
# 134/134 [==============================] - 33s 246ms/step - loss: 0.0591 - accuracy: 0.9829 - val_loss: 0.0208 - val_accuracy: 0.9988
# Epoch 8/10
# 134/134 [==============================] - 33s 249ms/step - loss: 0.0547 - accuracy: 0.9836 - val_loss: 0.0203 - val_accuracy: 0.9976
# Epoch 9/10
# 134/134 [==============================] - 33s 247ms/step - loss: 0.0472 - accuracy: 0.9870 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 10/10
# 134/134 [==============================] - 33s 244ms/step - loss: 0.0447 - accuracy: 0.9872 - val_loss: 0.0152 - val_accuracy: 0.9979
# 58/58 [==============================] - 1s 19ms/step
# Avg accuracy : 0.9674344496524558
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      9258
#            1       0.99      0.94      0.97      9258
#
#     accuracy                           0.97     18516
#    macro avg       0.97      0.97      0.97     18516
# weighted avg       0.97      0.97      0.97     18516

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply undersampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = lstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = lstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# C:\Users\Younas\AppData\Local\Temp\ipykernel_12872\301967346.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_12872\301967346.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 11/11 [==============================] - 10s 477ms/step - loss: 0.6734 - accuracy: 0.6069 - val_loss: 1.3851 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 3s 277ms/step - loss: 0.6567 - accuracy: 0.6238 - val_loss: 0.8301 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 3s 293ms/step - loss: 0.6112 - accuracy: 0.6248 - val_loss: 1.0701 - val_accuracy: 0.0037
# 5/5 [==============================] - 0s 21ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 291ms/step - loss: 0.6218 - accuracy: 0.6417 - val_loss: 0.9145 - val_accuracy: 0.1311
# Epoch 2/10
# 11/11 [==============================] - 3s 287ms/step - loss: 0.5520 - accuracy: 0.7205 - val_loss: 0.8762 - val_accuracy: 0.4345
# Epoch 3/10
# 11/11 [==============================] - 3s 296ms/step - loss: 0.4486 - accuracy: 0.8021 - val_loss: 0.8054 - val_accuracy: 0.6180
# Epoch 4/10
# 11/11 [==============================] - 3s 307ms/step - loss: 0.3777 - accuracy: 0.8330 - val_loss: 0.7383 - val_accuracy: 0.6442
# Epoch 5/10
# 11/11 [==============================] - 3s 293ms/step - loss: 0.3087 - accuracy: 0.8734 - val_loss: 0.8892 - val_accuracy: 0.5805
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 306ms/step - loss: 0.6500 - accuracy: 0.6598 - val_loss: 0.7966 - val_accuracy: 0.5056
# Epoch 2/10
# 11/11 [==============================] - 3s 298ms/step - loss: 0.5432 - accuracy: 0.7366 - val_loss: 0.8948 - val_accuracy: 0.4195
# 5/5 [==============================] - 0s 23ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 299ms/step - loss: 0.6328 - accuracy: 0.6485 - val_loss: 0.8911 - val_accuracy: 0.4120
# Epoch 2/10
# 11/11 [==============================] - 3s 298ms/step - loss: 0.5648 - accuracy: 0.7067 - val_loss: 1.0314 - val_accuracy: 0.3371
# 5/5 [==============================] - 0s 23ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 302ms/step - loss: 0.5765 - accuracy: 0.6851 - val_loss: 0.8382 - val_accuracy: 0.4981
# Epoch 2/10
# 11/11 [==============================] - 3s 295ms/step - loss: 0.5147 - accuracy: 0.7404 - val_loss: 0.7125 - val_accuracy: 0.6255
# Epoch 3/10
# 11/11 [==============================] - 3s 297ms/step - loss: 0.4551 - accuracy: 0.7779 - val_loss: 0.9533 - val_accuracy: 0.5393
# 5/5 [==============================] - 0s 19ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 294ms/step - loss: 0.5801 - accuracy: 0.7001 - val_loss: 0.8334 - val_accuracy: 0.5618
# Epoch 2/10
# 11/11 [==============================] - 3s 298ms/step - loss: 0.5113 - accuracy: 0.7441 - val_loss: 1.0932 - val_accuracy: 0.4307
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 298ms/step - loss: 0.5687 - accuracy: 0.7123 - val_loss: 0.7199 - val_accuracy: 0.6517
# Epoch 2/10
# 11/11 [==============================] - 3s 289ms/step - loss: 0.5216 - accuracy: 0.7366 - val_loss: 0.9139 - val_accuracy: 0.5431
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 312ms/step - loss: 0.5618 - accuracy: 0.6917 - val_loss: 0.7359 - val_accuracy: 0.6292
# Epoch 2/10
# 11/11 [==============================] - 3s 288ms/step - loss: 0.5081 - accuracy: 0.7376 - val_loss: 0.8863 - val_accuracy: 0.5281
# 5/5 [==============================] - 0s 20ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 304ms/step - loss: 0.5837 - accuracy: 0.6917 - val_loss: 0.8344 - val_accuracy: 0.5318
# Epoch 2/10
# 11/11 [==============================] - 3s 296ms/step - loss: 0.5259 - accuracy: 0.7282 - val_loss: 0.9522 - val_accuracy: 0.5019
# 5/5 [==============================] - 0s 21ms/step
# Epoch 1/10
# 11/11 [==============================] - 3s 303ms/step - loss: 0.5639 - accuracy: 0.6860 - val_loss: 0.7728 - val_accuracy: 0.6067
# Epoch 2/10
# 11/11 [==============================] - 3s 298ms/step - loss: 0.5294 - accuracy: 0.7226 - val_loss: 0.9080 - val_accuracy: 0.5281
# 5/5 [==============================] - 0s 18ms/step
# Avg accuracy : 0.6565935062579358
#               precision    recall  f1-score   support
#
#            0       0.61      0.88      0.72       741
#            1       0.78      0.43      0.56       741
#
#     accuracy                           0.66      1482
#    macro avg       0.69      0.66      0.64      1482
# weighted avg       0.69      0.66      0.64      1482

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predicted_targets = []
    all_actual_targets = []
    tprs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Compile and train the model
        model = build_LSTM_model()
        model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Evaluate the model
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = model.predict(test_sequences_matrix).round().flatten()

        # ROC Curve
        fpr, tpr, _ = roc_curve(Test_Y, predictions)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        
        # Store actual and predicted values
        all_predicted_targets.extend(predictions)
        all_actual_targets.extend(Test_Y)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    return mean_fpr, mean_tpr, mean_auc, all_predicted_targets, all_actual_targets

# Get ROC data
mean_fpr_lstm, mean_tpr_lstm, mean_auc_lstm, all_predictions_lstm, all_actuals_lstm = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM (area = %0.2f)' % mean_auc_lstm)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for LSTM')
plt.legend(loc="lower right")
plt.show()

# Print classification report
print(classification_report(all_actuals_lstm, all_predictions_lstm))
# Out:
# Dataset loaded.
# NLTK data downloaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_12872\1442462283.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# Epoch 1/10
# 134/134 [==============================] - 67s 371ms/step - loss: 0.4546 - accuracy: 0.7825 - val_loss: 0.3747 - val_accuracy: 0.8449
# Epoch 2/10
# 134/134 [==============================] - 31s 229ms/step - loss: 0.2763 - accuracy: 0.8876 - val_loss: 0.3778 - val_accuracy: 0.8668
# 58/58 [==============================] - 1s 17ms/step
# Epoch 1/10
# 134/134 [==============================] - 50s 355ms/step - loss: 0.4401 - accuracy: 0.7907 - val_loss: 0.3441 - val_accuracy: 0.8821
# Epoch 2/10
# 134/134 [==============================] - 53s 398ms/step - loss: 0.2706 - accuracy: 0.8879 - val_loss: 0.3487 - val_accuracy: 0.8980
# 58/58 [==============================] - 2s 30ms/step
# Epoch 1/10
# 134/134 [==============================] - 58s 384ms/step - loss: 0.4391 - accuracy: 0.7896 - val_loss: 0.2968 - val_accuracy: 0.9067
# Epoch 2/10
# 134/134 [==============================] - 47s 354ms/step - loss: 0.2746 - accuracy: 0.8876 - val_loss: 0.5054 - val_accuracy: 0.7852
# 58/58 [==============================] - 3s 31ms/step
# Epoch 1/10
# 134/134 [==============================] - 58s 383ms/step - loss: 0.4370 - accuracy: 0.7888 - val_loss: 0.4142 - val_accuracy: 0.8350
# Epoch 2/10
# 134/134 [==============================] - 49s 363ms/step - loss: 0.2732 - accuracy: 0.8870 - val_loss: 0.3348 - val_accuracy: 0.8956
# Epoch 3/10
# 134/134 [==============================] - 52s 385ms/step - loss: 0.2208 - accuracy: 0.9155 - val_loss: 0.2260 - val_accuracy: 0.9463
# Epoch 4/10
# 134/134 [==============================] - 52s 386ms/step - loss: 0.1819 - accuracy: 0.9348 - val_loss: 0.1714 - val_accuracy: 0.9754
# Epoch 5/10
# 134/134 [==============================] - 51s 382ms/step - loss: 0.1636 - accuracy: 0.9409 - val_loss: 0.1612 - val_accuracy: 0.9646
# Epoch 6/10
# 134/134 [==============================] - 52s 387ms/step - loss: 0.1317 - accuracy: 0.9549 - val_loss: 0.1095 - val_accuracy: 0.9928
# Epoch 7/10
# 134/134 [==============================] - 49s 369ms/step - loss: 0.1110 - accuracy: 0.9629 - val_loss: 0.0812 - val_accuracy: 0.9898
# Epoch 8/10
# 134/134 [==============================] - 51s 381ms/step - loss: 0.1009 - accuracy: 0.9675 - val_loss: 0.0669 - val_accuracy: 0.9898
# Epoch 9/10
# 134/134 [==============================] - 51s 384ms/step - loss: 0.0980 - accuracy: 0.9692 - val_loss: 0.0886 - val_accuracy: 0.9835
# 58/58 [==============================] - 3s 32ms/step
# Epoch 1/10
# 134/134 [==============================] - 105s 734ms/step - loss: 0.4549 - accuracy: 0.7835 - val_loss: 0.4593 - val_accuracy: 0.8239
# Epoch 2/10
# 134/134 [==============================] - 55s 414ms/step - loss: 0.2799 - accuracy: 0.8855 - val_loss: 0.2742 - val_accuracy: 0.9409
# Epoch 3/10
# 134/134 [==============================] - 55s 412ms/step - loss: 0.2282 - accuracy: 0.9125 - val_loss: 0.1841 - val_accuracy: 0.9670
# Epoch 4/10
# 134/134 [==============================] - 55s 409ms/step - loss: 0.1875 - accuracy: 0.9315 - val_loss: 0.1708 - val_accuracy: 0.9652
# Epoch 5/10
# 134/134 [==============================] - 55s 410ms/step - loss: 0.1520 - accuracy: 0.9461 - val_loss: 0.1608 - val_accuracy: 0.9634
# Epoch 6/10
# 134/134 [==============================] - 67s 501ms/step - loss: 0.1284 - accuracy: 0.9569 - val_loss: 0.1103 - val_accuracy: 0.9904
# Epoch 7/10
# 134/134 [==============================] - 75s 559ms/step - loss: 0.1130 - accuracy: 0.9624 - val_loss: 0.0706 - val_accuracy: 0.9886
# Epoch 8/10
# 134/134 [==============================] - 51s 384ms/step - loss: 0.0930 - accuracy: 0.9707 - val_loss: 0.0583 - val_accuracy: 0.9952
# Epoch 9/10
# 134/134 [==============================] - 51s 384ms/step - loss: 0.0873 - accuracy: 0.9722 - val_loss: 0.0489 - val_accuracy: 0.9982
# Epoch 10/10
# 134/134 [==============================] - 51s 384ms/step - loss: 0.0714 - accuracy: 0.9791 - val_loss: 0.0494 - val_accuracy: 0.9934
# 58/58 [==============================] - 2s 26ms/step
# Epoch 1/10
# 134/134 [==============================] - 46s 322ms/step - loss: 0.4497 - accuracy: 0.7826 - val_loss: 0.3536 - val_accuracy: 0.8665
# Epoch 2/10
# 134/134 [==============================] - 40s 298ms/step - loss: 0.2706 - accuracy: 0.8891 - val_loss: 0.2256 - val_accuracy: 0.9382
# Epoch 3/10
# 134/134 [==============================] - 40s 297ms/step - loss: 0.2100 - accuracy: 0.9206 - val_loss: 0.2102 - val_accuracy: 0.9586
# Epoch 4/10
# 134/134 [==============================] - 40s 300ms/step - loss: 0.1638 - accuracy: 0.9431 - val_loss: 0.1419 - val_accuracy: 0.9799
# Epoch 5/10
# 134/134 [==============================] - 40s 299ms/step - loss: 0.1334 - accuracy: 0.9554 - val_loss: 0.1125 - val_accuracy: 0.9859
# Epoch 6/10
# 134/134 [==============================] - 40s 300ms/step - loss: 0.1186 - accuracy: 0.9605 - val_loss: 0.1042 - val_accuracy: 0.9835
# Epoch 7/10
# 134/134 [==============================] - 40s 300ms/step - loss: 0.1058 - accuracy: 0.9653 - val_loss: 0.1132 - val_accuracy: 0.9793
# 58/58 [==============================] - 1s 22ms/step
# Epoch 1/10
# 134/134 [==============================] - 42s 292ms/step - loss: 0.4401 - accuracy: 0.7895 - val_loss: 0.2901 - val_accuracy: 0.8899
# Epoch 2/10
# 134/134 [==============================] - 39s 289ms/step - loss: 0.2773 - accuracy: 0.8865 - val_loss: 0.3950 - val_accuracy: 0.8539
# 58/58 [==============================] - 1s 19ms/step
# Epoch 1/10
# 134/134 [==============================] - 76s 545ms/step - loss: 0.4462 - accuracy: 0.7839 - val_loss: 0.4153 - val_accuracy: 0.8281
# Epoch 2/10
# 134/134 [==============================] - 73s 547ms/step - loss: 0.2768 - accuracy: 0.8889 - val_loss: 0.2608 - val_accuracy: 0.9307
# Epoch 3/10
# 134/134 [==============================] - 73s 547ms/step - loss: 0.2129 - accuracy: 0.9188 - val_loss: 0.1837 - val_accuracy: 0.9604
# Epoch 4/10
# 134/134 [==============================] - 73s 547ms/step - loss: 0.1692 - accuracy: 0.9383 - val_loss: 0.1129 - val_accuracy: 0.9847
# Epoch 5/10
# 134/134 [==============================] - 73s 547ms/step - loss: 0.1426 - accuracy: 0.9509 - val_loss: 0.1255 - val_accuracy: 0.9820
# 58/58 [==============================] - 2s 31ms/step
# Epoch 1/10
# 134/134 [==============================] - 68s 492ms/step - loss: 0.4444 - accuracy: 0.7840 - val_loss: 0.3676 - val_accuracy: 0.8488
# Epoch 2/10
# 134/134 [==============================] - 62s 463ms/step - loss: 0.2807 - accuracy: 0.8862 - val_loss: 0.2891 - val_accuracy: 0.9082
# Epoch 3/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.2205 - accuracy: 0.9167 - val_loss: 0.2258 - val_accuracy: 0.9595
# Epoch 4/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.1782 - accuracy: 0.9350 - val_loss: 0.2014 - val_accuracy: 0.9559
# Epoch 5/10
# 134/134 [==============================] - 62s 460ms/step - loss: 0.1411 - accuracy: 0.9503 - val_loss: 0.1236 - val_accuracy: 0.9823
# Epoch 6/10
# 134/134 [==============================] - 62s 465ms/step - loss: 0.1263 - accuracy: 0.9563 - val_loss: 0.0851 - val_accuracy: 0.9958
# Epoch 7/10
# 134/134 [==============================] - 62s 461ms/step - loss: 0.1050 - accuracy: 0.9668 - val_loss: 0.0820 - val_accuracy: 0.9934
# Epoch 8/10
# 134/134 [==============================] - 62s 465ms/step - loss: 0.0936 - accuracy: 0.9708 - val_loss: 0.0793 - val_accuracy: 0.9880
# Epoch 9/10
# 134/134 [==============================] - 62s 465ms/step - loss: 0.1021 - accuracy: 0.9671 - val_loss: 0.0716 - val_accuracy: 0.9985
# Epoch 10/10
# 134/134 [==============================] - 62s 462ms/step - loss: 0.0772 - accuracy: 0.9773 - val_loss: 0.0422 - val_accuracy: 0.9985
# 58/58 [==============================] - 1s 22ms/step
# Epoch 1/10
# 134/134 [==============================] - 52s 369ms/step - loss: 0.4465 - accuracy: 0.7840 - val_loss: 0.4521 - val_accuracy: 0.8107
# Epoch 2/10
# 134/134 [==============================] - 48s 360ms/step - loss: 0.2705 - accuracy: 0.8887 - val_loss: 0.3808 - val_accuracy: 0.8395
# Epoch 3/10
# 134/134 [==============================] - 49s 364ms/step - loss: 0.2147 - accuracy: 0.9139 - val_loss: 0.2347 - val_accuracy: 0.9142
# Epoch 4/10
# 134/134 [==============================] - 49s 365ms/step - loss: 0.1745 - accuracy: 0.9356 - val_loss: 0.1258 - val_accuracy: 0.9796
# Epoch 5/10
# 134/134 [==============================] - 49s 369ms/step - loss: 0.1403 - accuracy: 0.9521 - val_loss: 0.1374 - val_accuracy: 0.9736
# 58/58 [==============================] - 1s 21ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      9258
#            1       0.93      0.92      0.93      9258
#
#     accuracy                           0.93     18516
#    macro avg       0.93      0.93      0.93     18516
# weighted avg       0.93      0.93      0.93     18516

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply undersampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the LSTM model
def build_LSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
lstm_model = build_LSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predicted_targets = []
    all_actual_targets = []
    tprs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Compile and train the model
        model = build_LSTM_model()
        model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Evaluate the model
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = model.predict(test_sequences_matrix).round().flatten()

        # ROC Curve
        fpr, tpr, _ = roc_curve(Test_Y, predictions)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        
        # Store actual and predicted values
        all_predicted_targets.extend(predictions)
        all_actual_targets.extend(Test_Y)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    return mean_fpr, mean_tpr, mean_auc, all_predicted_targets, all_actual_targets

# Get ROC data
mean_fpr_lstm_under, mean_tpr_lstm_under, mean_auc_lstm_under, all_predictions_lstm_under, all_actuals_lstm_under = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Print classification report
print(classification_report(all_actuals_lstm_under, all_predictions_lstm_under))
# Out:
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# C:\Users\Younas\AppData\Local\Temp\ipykernel_12872\851246314.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# Epoch 1/10
# 11/11 [==============================] - 7s 416ms/step - loss: 0.6722 - accuracy: 0.6116 - val_loss: 1.2832 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 4s 364ms/step - loss: 0.6351 - accuracy: 0.6238 - val_loss: 0.8993 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 4s 352ms/step - loss: 0.5772 - accuracy: 0.6510 - val_loss: 0.7943 - val_accuracy: 0.4419
# Epoch 4/10
# 11/11 [==============================] - 4s 351ms/step - loss: 0.4539 - accuracy: 0.8124 - val_loss: 0.8027 - val_accuracy: 0.6180
# 5/5 [==============================] - 0s 35ms/step
# Epoch 1/10
# 11/11 [==============================] - 9s 560ms/step - loss: 0.6738 - accuracy: 0.6144 - val_loss: 1.0152 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 6s 532ms/step - loss: 0.6252 - accuracy: 0.6313 - val_loss: 0.9505 - val_accuracy: 0.0037
# Epoch 3/10
# 11/11 [==============================] - 6s 530ms/step - loss: 0.5828 - accuracy: 0.6857 - val_loss: 0.8240 - val_accuracy: 0.3446
# Epoch 4/10
# 11/11 [==============================] - 6s 537ms/step - loss: 0.5012 - accuracy: 0.8236 - val_loss: 0.7953 - val_accuracy: 0.4607
# Epoch 5/10
# 11/11 [==============================] - 6s 530ms/step - loss: 0.4238 - accuracy: 0.8386 - val_loss: 0.9704 - val_accuracy: 0.4869
# 5/5 [==============================] - 0s 33ms/step
# Epoch 1/10
# 11/11 [==============================] - 8s 535ms/step - loss: 0.6786 - accuracy: 0.6054 - val_loss: 1.1151 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 6s 504ms/step - loss: 0.6387 - accuracy: 0.6242 - val_loss: 0.9508 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 6s 503ms/step - loss: 0.5697 - accuracy: 0.6804 - val_loss: 0.7812 - val_accuracy: 0.5131
# Epoch 4/10
# 11/11 [==============================] - 6s 500ms/step - loss: 0.4974 - accuracy: 0.7929 - val_loss: 0.6988 - val_accuracy: 0.6067
# Epoch 5/10
# 11/11 [==============================] - 6s 501ms/step - loss: 0.4355 - accuracy: 0.8276 - val_loss: 0.7532 - val_accuracy: 0.6030
# 5/5 [==============================] - 0s 49ms/step
# Epoch 1/10
# 11/11 [==============================] - 8s 458ms/step - loss: 0.6760 - accuracy: 0.6054 - val_loss: 1.0735 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 431ms/step - loss: 0.6404 - accuracy: 0.6251 - val_loss: 0.8667 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 5s 431ms/step - loss: 0.6007 - accuracy: 0.6326 - val_loss: 0.9786 - val_accuracy: 0.0375
# 5/5 [==============================] - 0s 26ms/step
# Epoch 1/10
# 11/11 [==============================] - 7s 443ms/step - loss: 0.6757 - accuracy: 0.6045 - val_loss: 1.0540 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 4s 406ms/step - loss: 0.6401 - accuracy: 0.6186 - val_loss: 0.9110 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 5s 414ms/step - loss: 0.5717 - accuracy: 0.6589 - val_loss: 0.7829 - val_accuracy: 0.4457
# Epoch 4/10
# 11/11 [==============================] - 5s 428ms/step - loss: 0.4455 - accuracy: 0.8135 - val_loss: 0.7198 - val_accuracy: 0.6592
# Epoch 5/10
# 11/11 [==============================] - 5s 434ms/step - loss: 0.3587 - accuracy: 0.8369 - val_loss: 0.7384 - val_accuracy: 0.6592
# 5/5 [==============================] - 0s 28ms/step
# Epoch 1/10
# 11/11 [==============================] - 9s 526ms/step - loss: 0.6728 - accuracy: 0.6242 - val_loss: 1.1487 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 496ms/step - loss: 0.6361 - accuracy: 0.6270 - val_loss: 0.8824 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 5s 494ms/step - loss: 0.5855 - accuracy: 0.6354 - val_loss: 1.1278 - val_accuracy: 0.0412
# 5/5 [==============================] - 0s 28ms/step
# Epoch 1/10
# 11/11 [==============================] - 8s 490ms/step - loss: 0.6782 - accuracy: 0.6082 - val_loss: 1.0427 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 458ms/step - loss: 0.6372 - accuracy: 0.6195 - val_loss: 0.8146 - val_accuracy: 0.0075
# Epoch 3/10
# 11/11 [==============================] - 5s 457ms/step - loss: 0.5943 - accuracy: 0.6664 - val_loss: 1.0189 - val_accuracy: 0.1199
# 5/5 [==============================] - 0s 26ms/step
# Epoch 1/10
# 11/11 [==============================] - 8s 473ms/step - loss: 0.6744 - accuracy: 0.6186 - val_loss: 1.0594 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 445ms/step - loss: 0.6247 - accuracy: 0.6298 - val_loss: 0.9342 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 5s 445ms/step - loss: 0.5610 - accuracy: 0.6842 - val_loss: 0.7884 - val_accuracy: 0.3820
# Epoch 4/10
# 11/11 [==============================] - 5s 443ms/step - loss: 0.4503 - accuracy: 0.8135 - val_loss: 0.6824 - val_accuracy: 0.7228
# Epoch 5/10
# 11/11 [==============================] - 5s 445ms/step - loss: 0.3560 - accuracy: 0.8397 - val_loss: 0.8547 - val_accuracy: 0.6404
# 5/5 [==============================] - 0s 24ms/step
# Epoch 1/10
# 11/11 [==============================] - 7s 449ms/step - loss: 0.6805 - accuracy: 0.6092 - val_loss: 0.9311 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 418ms/step - loss: 0.6343 - accuracy: 0.6242 - val_loss: 1.0097 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 0s 25ms/step
# Epoch 1/10
# 11/11 [==============================] - 7s 446ms/step - loss: 0.6740 - accuracy: 0.6251 - val_loss: 1.1268 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 413ms/step - loss: 0.6387 - accuracy: 0.6279 - val_loss: 0.8703 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 11/11 [==============================] - 5s 412ms/step - loss: 0.5806 - accuracy: 0.6373 - val_loss: 1.2540 - val_accuracy: 0.0449
# 5/5 [==============================] - 0s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.92      0.71       741
#            1       0.80      0.32      0.46       741
#
#     accuracy                           0.62      1482
#    macro avg       0.69      0.62      0.59      1482
# weighted avg       0.69      0.62      0.59      1482

# %%
# Plot Combined ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM Oversampling (area = %0.2f)' % mean_auc_lstm)
plt.plot(mean_fpr_lstm_under, mean_tpr_lstm_under, color='green', lw=2, label='ROC curve LSTM Undersampling (area = %0.2f)' % mean_auc_lstm_under)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Combined ROC Curve for LSTM')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot Combined ROC Curve
plt.figure()
plt.plot(mean_fpr_lstm, mean_tpr_lstm, color='blue', lw=2, label='ROC curve LSTM Oversampling (area = %0.2f)' % mean_auc_lstm)
plt.plot(mean_fpr_lstm_under, mean_tpr_lstm_under, color='green', lw=2, label='ROC curve LSTM Undersampling (area = %0.2f)' % mean_auc_lstm_under)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Combined ROC Curve for LSTM')
plt.legend(loc="lower right")
# Save the plot
plt.savefig('combined_roc_curve_lstm.png', dpi=300)
plt.show()
