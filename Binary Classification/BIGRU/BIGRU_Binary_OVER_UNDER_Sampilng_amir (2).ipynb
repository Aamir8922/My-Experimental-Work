# %%
# Import necessary library
import pandas as pd

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')

# Initial dataset shape
print("Initial dataset shape:", dataset.shape)

# Drop rows where 'comment_Text' or 'Annotation' is NaN
dataset.dropna(subset=['comment_Text', 'Annotation'], inplace=True)

# New dataset shape after dropping NaN values
print("New dataset shape after dropping NaN values:", dataset.shape)

# Save the cleaned dataset to a new CSV file
dataset.to_csv('Binary_Classification.csv', index=False, encoding='latin-1')

print("Cleaned dataset saved as 'Binary_Classification.csv'.")
# Out:
# C:\Users\Younas\AppData\Local\Temp\ipykernel_15304\2587685516.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Initial dataset shape: (9999, 7)
# New dataset shape after dropping NaN values: (9999, 7)
# Cleaned dataset saved as 'Binary_Classification.csv'.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.over_sampling import RandomOverSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the BiLSTM model
def build_BiLSTM_model():
    model = Sequential()
    model.add(Embedding(max_words, 100, input_length=max_len))
    model.add(SpatialDropout1D(0.2))
    model.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Instantiate the model
bilstm_model = build_BiLSTM_model()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Train the model
        history = bilstm_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = bilstm_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# C:\Users\Younas\AppData\Local\Temp\ipykernel_6120\2651253809.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Dataset loaded.
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     self signed certificate (_ssl.c:1129)>
# [nltk_data] Error loading wordnet: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     self signed certificate (_ssl.c:1129)>
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify
# [nltk_data]     failed: self signed certificate (_ssl.c:1129)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     self signed certificate (_ssl.c:1129)>
# [nltk_data] Error loading omw-1.4: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     self signed certificate (_ssl.c:1129)>
# C:\Users\Younas\AppData\Local\Temp\ipykernel_6120\2651253809.py:38: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# NLTK data downloaded.
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Younas\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 134/134 [==============================] - 95s 668ms/step - loss: 0.4502 - accuracy: 0.7805 - val_loss: 0.3466 - val_accuracy: 0.8776
# Epoch 2/10
# 134/134 [==============================] - 99s 740ms/step - loss: 0.2722 - accuracy: 0.8931 - val_loss: 0.2666 - val_accuracy: 0.9301
# Epoch 3/10
# 134/134 [==============================] - 104s 778ms/step - loss: 0.2062 - accuracy: 0.9229 - val_loss: 0.2023 - val_accuracy: 0.9655
# Epoch 4/10
# 134/134 [==============================] - 104s 778ms/step - loss: 0.1611 - accuracy: 0.9438 - val_loss: 0.1444 - val_accuracy: 0.9748
# Epoch 5/10
# 134/134 [==============================] - 106s 793ms/step - loss: 0.1327 - accuracy: 0.9551 - val_loss: 0.1395 - val_accuracy: 0.9760
# Epoch 6/10
# 134/134 [==============================] - 109s 811ms/step - loss: 0.1118 - accuracy: 0.9631 - val_loss: 0.1253 - val_accuracy: 0.9721
# Epoch 7/10
# 134/134 [==============================] - 110s 821ms/step - loss: 0.1035 - accuracy: 0.9659 - val_loss: 0.0916 - val_accuracy: 0.9772
# Epoch 8/10
# 134/134 [==============================] - 105s 783ms/step - loss: 0.0929 - accuracy: 0.9708 - val_loss: 0.0598 - val_accuracy: 0.9934
# Epoch 9/10
# 134/134 [==============================] - 110s 822ms/step - loss: 0.0836 - accuracy: 0.9748 - val_loss: 0.0708 - val_accuracy: 0.9898
# 58/58 [==============================] - 2s 27ms/step
# Epoch 1/10
# 134/134 [==============================] - 108s 805ms/step - loss: 0.6352 - accuracy: 0.6846 - val_loss: 0.6267 - val_accuracy: 0.7009
# Epoch 2/10
# 134/134 [==============================] - 108s 806ms/step - loss: 0.4040 - accuracy: 0.8174 - val_loss: 0.5389 - val_accuracy: 0.7597
# Epoch 3/10
# 134/134 [==============================] - 117s 877ms/step - loss: 0.3021 - accuracy: 0.8769 - val_loss: 0.4880 - val_accuracy: 0.7921
# Epoch 4/10
# 134/134 [==============================] - 113s 842ms/step - loss: 0.2350 - accuracy: 0.9096 - val_loss: 0.1891 - val_accuracy: 0.9607
# Epoch 5/10
# 134/134 [==============================] - 113s 844ms/step - loss: 0.1843 - accuracy: 0.9324 - val_loss: 0.1190 - val_accuracy: 0.9859
# Epoch 6/10
# 134/134 [==============================] - 114s 853ms/step - loss: 0.1549 - accuracy: 0.9448 - val_loss: 0.1548 - val_accuracy: 0.9658
# 58/58 [==============================] - 2s 28ms/step
# Epoch 1/10
# 134/134 [==============================] - 115s 860ms/step - loss: 0.5245 - accuracy: 0.7451 - val_loss: 0.5588 - val_accuracy: 0.7312
# Epoch 2/10
# 134/134 [==============================] - 115s 858ms/step - loss: 0.3209 - accuracy: 0.8649 - val_loss: 0.3164 - val_accuracy: 0.8917
# Epoch 3/10
# 134/134 [==============================] - 115s 857ms/step - loss: 0.2228 - accuracy: 0.9142 - val_loss: 0.1491 - val_accuracy: 0.9787
# Epoch 4/10
# 134/134 [==============================] - 109s 813ms/step - loss: 0.1625 - accuracy: 0.9428 - val_loss: 0.1087 - val_accuracy: 0.9826
# Epoch 5/10
# 134/134 [==============================] - 114s 848ms/step - loss: 0.1247 - accuracy: 0.9587 - val_loss: 0.0988 - val_accuracy: 0.9904
# Epoch 6/10
# 134/134 [==============================] - 116s 866ms/step - loss: 0.1028 - accuracy: 0.9673 - val_loss: 0.0648 - val_accuracy: 0.9946
# Epoch 7/10
# 134/134 [==============================] - 114s 853ms/step - loss: 0.0859 - accuracy: 0.9734 - val_loss: 0.0492 - val_accuracy: 0.9973
# Epoch 8/10
# 134/134 [==============================] - 109s 814ms/step - loss: 0.0773 - accuracy: 0.9766 - val_loss: 0.0486 - val_accuracy: 0.9991
# Epoch 9/10
# 134/134 [==============================] - 109s 816ms/step - loss: 0.0665 - accuracy: 0.9798 - val_loss: 0.0575 - val_accuracy: 0.9937
# 58/58 [==============================] - 2s 37ms/step
# Epoch 1/10
# 134/134 [==============================] - 116s 867ms/step - loss: 0.5303 - accuracy: 0.7702 - val_loss: 0.4426 - val_accuracy: 0.8062
# Epoch 2/10
# 134/134 [==============================] - 114s 853ms/step - loss: 0.2925 - accuracy: 0.8768 - val_loss: 0.3246 - val_accuracy: 0.8947
# Epoch 3/10
# 134/134 [==============================] - 115s 857ms/step - loss: 0.1921 - accuracy: 0.9275 - val_loss: 0.2248 - val_accuracy: 0.9397
# Epoch 4/10
# 134/134 [==============================] - 116s 867ms/step - loss: 0.1388 - accuracy: 0.9527 - val_loss: 0.1245 - val_accuracy: 0.9787
# Epoch 5/10
# 134/134 [==============================] - 120s 895ms/step - loss: 0.1092 - accuracy: 0.9641 - val_loss: 0.0835 - val_accuracy: 0.9922
# Epoch 6/10
# 134/134 [==============================] - 117s 877ms/step - loss: 0.0908 - accuracy: 0.9708 - val_loss: 0.0669 - val_accuracy: 0.9946
# Epoch 7/10
# 134/134 [==============================] - 116s 868ms/step - loss: 0.0807 - accuracy: 0.9751 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 8/10
# 134/134 [==============================] - 118s 883ms/step - loss: 0.0685 - accuracy: 0.9800 - val_loss: 0.0724 - val_accuracy: 0.9928
# 58/58 [==============================] - 2s 37ms/step
# Epoch 1/10
# 134/134 [==============================] - 116s 868ms/step - loss: 0.5767 - accuracy: 0.7370 - val_loss: 0.5125 - val_accuracy: 0.7561
# Epoch 2/10
# 134/134 [==============================] - 117s 871ms/step - loss: 0.3304 - accuracy: 0.8544 - val_loss: 0.3110 - val_accuracy: 0.9013
# Epoch 3/10
# 134/134 [==============================] - 114s 849ms/step - loss: 0.2272 - accuracy: 0.9103 - val_loss: 0.2166 - val_accuracy: 0.9520
# Epoch 4/10
# 134/134 [==============================] - 114s 849ms/step - loss: 0.1587 - accuracy: 0.9425 - val_loss: 0.1257 - val_accuracy: 0.9796
# Epoch 5/10
# 134/134 [==============================] - 117s 870ms/step - loss: 0.1199 - accuracy: 0.9592 - val_loss: 0.0606 - val_accuracy: 0.9970
# Epoch 6/10
# 134/134 [==============================] - 112s 838ms/step - loss: 0.0926 - accuracy: 0.9699 - val_loss: 0.0719 - val_accuracy: 0.9928
# 58/58 [==============================] - 2s 28ms/step
# Epoch 1/10
# 134/134 [==============================] - 114s 848ms/step - loss: 0.5205 - accuracy: 0.7753 - val_loss: 0.3493 - val_accuracy: 0.8695
# Epoch 2/10
# 134/134 [==============================] - 113s 846ms/step - loss: 0.2742 - accuracy: 0.8822 - val_loss: 0.2079 - val_accuracy: 0.9562
# Epoch 3/10
# 134/134 [==============================] - 115s 860ms/step - loss: 0.1844 - accuracy: 0.9308 - val_loss: 0.1419 - val_accuracy: 0.9826
# Epoch 4/10
# 134/134 [==============================] - 116s 867ms/step - loss: 0.1347 - accuracy: 0.9558 - val_loss: 0.0998 - val_accuracy: 0.9868
# Epoch 5/10
# 134/134 [==============================] - 120s 894ms/step - loss: 0.1054 - accuracy: 0.9663 - val_loss: 0.0720 - val_accuracy: 0.9898
# Epoch 6/10
# 134/134 [==============================] - 119s 891ms/step - loss: 0.0881 - accuracy: 0.9715 - val_loss: 0.0852 - val_accuracy: 0.9841
# 58/58 [==============================] - 2s 35ms/step
# Epoch 1/10
# 134/134 [==============================] - 112s 837ms/step - loss: 0.5673 - accuracy: 0.7469 - val_loss: 0.3664 - val_accuracy: 0.8686
# Epoch 2/10
# 134/134 [==============================] - 111s 828ms/step - loss: 0.3020 - accuracy: 0.8677 - val_loss: 0.3001 - val_accuracy: 0.9055
# Epoch 3/10
# 134/134 [==============================] - 110s 824ms/step - loss: 0.2034 - accuracy: 0.9221 - val_loss: 0.1728 - val_accuracy: 0.9703
# Epoch 4/10
# 134/134 [==============================] - 110s 818ms/step - loss: 0.1470 - accuracy: 0.9467 - val_loss: 0.1050 - val_accuracy: 0.9889
# Epoch 5/10
# 134/134 [==============================] - 117s 870ms/step - loss: 0.1081 - accuracy: 0.9647 - val_loss: 0.0689 - val_accuracy: 0.9955
# Epoch 6/10
# 134/134 [==============================] - 113s 844ms/step - loss: 0.0897 - accuracy: 0.9697 - val_loss: 0.0583 - val_accuracy: 0.9964
# Epoch 7/10
# 134/134 [==============================] - 113s 840ms/step - loss: 0.0752 - accuracy: 0.9771 - val_loss: 0.0370 - val_accuracy: 0.9964
# Epoch 8/10
# 134/134 [==============================] - 116s 863ms/step - loss: 0.0632 - accuracy: 0.9818 - val_loss: 0.0417 - val_accuracy: 0.9922
# 58/58 [==============================] - 2s 30ms/step
# Epoch 1/10
# 134/134 [==============================] - 112s 834ms/step - loss: 0.5097 - accuracy: 0.7809 - val_loss: 0.4220 - val_accuracy: 0.8242
# Epoch 2/10
# 134/134 [==============================] - 112s 833ms/step - loss: 0.2639 - accuracy: 0.8948 - val_loss: 0.2076 - val_accuracy: 0.9448
# Epoch 3/10
# 134/134 [==============================] - 112s 836ms/step - loss: 0.1872 - accuracy: 0.9317 - val_loss: 0.1368 - val_accuracy: 0.9817
# Epoch 4/10
# 134/134 [==============================] - 113s 845ms/step - loss: 0.1345 - accuracy: 0.9536 - val_loss: 0.1034 - val_accuracy: 0.9898
# Epoch 5/10
# 134/134 [==============================] - 109s 814ms/step - loss: 0.1053 - accuracy: 0.9657 - val_loss: 0.0576 - val_accuracy: 0.9973
# Epoch 6/10
# 134/134 [==============================] - 113s 846ms/step - loss: 0.0882 - accuracy: 0.9719 - val_loss: 0.0577 - val_accuracy: 0.9949
# 58/58 [==============================] - 2s 34ms/step
# Epoch 1/10
# 134/134 [==============================] - 116s 864ms/step - loss: 0.5134 - accuracy: 0.7719 - val_loss: 0.4434 - val_accuracy: 0.8137
# Epoch 2/10
# 134/134 [==============================] - 120s 896ms/step - loss: 0.2684 - accuracy: 0.8865 - val_loss: 0.2450 - val_accuracy: 0.9331
# Epoch 3/10
# 134/134 [==============================] - 117s 871ms/step - loss: 0.1769 - accuracy: 0.9359 - val_loss: 0.0972 - val_accuracy: 0.9952
# Epoch 4/10
# 134/134 [==============================] - 118s 882ms/step - loss: 0.1256 - accuracy: 0.9563 - val_loss: 0.0496 - val_accuracy: 0.9940
# Epoch 5/10
# 134/134 [==============================] - 119s 886ms/step - loss: 0.1000 - accuracy: 0.9673 - val_loss: 0.0403 - val_accuracy: 0.9979
# Epoch 6/10
# 134/134 [==============================] - 110s 820ms/step - loss: 0.0820 - accuracy: 0.9745 - val_loss: 0.0366 - val_accuracy: 0.9988
# Epoch 7/10
# 134/134 [==============================] - 115s 856ms/step - loss: 0.0696 - accuracy: 0.9782 - val_loss: 0.0334 - val_accuracy: 0.9976
# Epoch 8/10
# 134/134 [==============================] - 114s 851ms/step - loss: 0.0597 - accuracy: 0.9824 - val_loss: 0.0365 - val_accuracy: 0.9988
# 58/58 [==============================] - 2s 34ms/step
# Epoch 1/10
# 134/134 [==============================] - 112s 840ms/step - loss: 0.5089 - accuracy: 0.7887 - val_loss: 0.4011 - val_accuracy: 0.8419
# Epoch 2/10
# 134/134 [==============================] - 113s 840ms/step - loss: 0.2638 - accuracy: 0.8933 - val_loss: 0.2290 - val_accuracy: 0.9364
# Epoch 3/10
# 134/134 [==============================] - 114s 851ms/step - loss: 0.1752 - accuracy: 0.9353 - val_loss: 0.1185 - val_accuracy: 0.9877
# Epoch 4/10
# 134/134 [==============================] - 113s 841ms/step - loss: 0.1311 - accuracy: 0.9548 - val_loss: 0.0935 - val_accuracy: 0.9895
# Epoch 5/10
# 134/134 [==============================] - 119s 891ms/step - loss: 0.1014 - accuracy: 0.9677 - val_loss: 0.0536 - val_accuracy: 0.9967
# Epoch 6/10
# 134/134 [==============================] - 122s 910ms/step - loss: 0.0831 - accuracy: 0.9734 - val_loss: 0.0489 - val_accuracy: 0.9967
# Epoch 7/10
# 134/134 [==============================] - 126s 943ms/step - loss: 0.0692 - accuracy: 0.9791 - val_loss: 0.0329 - val_accuracy: 0.9991
# Epoch 8/10
# 134/134 [==============================] - 155s 1s/step - loss: 0.0590 - accuracy: 0.9820 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 9/10
# 134/134 [==============================] - 157s 1s/step - loss: 0.0506 - accuracy: 0.9852 - val_loss: 0.0251 - val_accuracy: 0.9991
# Epoch 10/10
# 134/134 [==============================] - 156s 1s/step - loss: 0.0514 - accuracy: 0.9863 - val_loss: 0.0273 - val_accuracy: 0.9985
# 58/58 [==============================] - 3s 43ms/step
# Avg accuracy : 0.9658146084131746
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      9258
#            1       0.99      0.94      0.96      9258
#
#     accuracy                           0.97     18516
#    macro avg       0.97      0.97      0.97     18516
# weighted avg       0.97      0.97      0.97     18516

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import re
import itertools
from keras.models import Model
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
import nltk
from collections import defaultdict
from sklearn.model_selection import KFold
from imblearn.under_sampling import RandomUnderSampler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, LSTM, Dense, SpatialDropout1D
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
from keras.layers import Input
from keras.layers import GRU, Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate

# Load your dataset
dataset = pd.read_csv('Binary_Classification.csv', encoding='latin-1')
print("Dataset loaded.")

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
nltk.download('omw-1.4')
print("NLTK data downloaded.")

# Define preprocessing functions
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_url(text):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)

def clean_text(text):
    REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\<\>\|@,;]')
    BAD_SYMBOLS_RE = re.compile('[^0-9a-z =#?+_]')
    text = strip_html(text) 
    text = remove_url(text)
    text = text.lower() 
    text = REPLACE_BY_SPACE_RE.sub(' ', text) 
    text = BAD_SYMBOLS_RE.sub('', text) 
    return text

# Preprocess dataset
dataset['comment_Text'] = dataset['comment_Text'].apply(clean_text)
dataset['comment_Text'].dropna(inplace=True)
dataset['comment_Text'] = [entry.lower() for entry in dataset['comment_Text']]
dataset['comment_Text'] = [word_tokenize(entry) for entry in dataset['comment_Text']]

tag_map = defaultdict(lambda: wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index, entry in enumerate(dataset['comment_Text']):
    Final_words = []
    word_Lemmatized = WordNetLemmatizer()
    for word, tag in pos_tag(entry):
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word, tag_map[tag[0]])
            Final_words.append(word_Final)
    dataset.loc[index, 'text_final'] = str(Final_words)

# Map 'Yes'/'No' to 1/0
dataset['Annotation'] = dataset['Annotation'].map({'Functional': 1, 'Non_Functional': 0})

# Apply oversampling to balance the classes
X = dataset['text_final']
y = dataset['Annotation']
undersampler = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = undersampler.fit_resample(np.array(X).reshape(-1, 1), y)

# Set parameters for the model
max_words = 1000
max_len = 150

# Define the bidirectional GRU classifier
def bidirectionalGRUclassifier():
    sequence_input = Input(shape=[max_len], name='inputs')
    model = Embedding(max_words, 100, input_length=max_len)(sequence_input)
    model = SpatialDropout1D(0.5)(model)
    model = Bidirectional(GRU(8, return_sequences=True, dropout=0.5, recurrent_dropout=0.1))(model)
    model = Conv1D(8, kernel_size=3, padding="valid", kernel_initializer="glorot_uniform")(model)
    avg_pool = GlobalAveragePooling1D()(model)
    max_pool = GlobalMaxPooling1D()(model)
    model = concatenate([avg_pool, max_pool]) 
    preds = Dense(1, activation="sigmoid")(model)
    return Model(inputs=sequence_input, outputs=preds)

# Instantiate the model
bidirectionalGRU_model = bidirectionalGRUclassifier()

# Function to perform training and evaluation
def get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len):
    k = 10
    kf = KFold(n_splits=k, shuffle=True, random_state=1)
    acc_score = []
    all_predictions = []
    all_actuals = []

    for train_index, test_index in kf.split(X_resampled):
        Train_X, Test_X = X_resampled[train_index], X_resampled[test_index]
        Train_Y, Test_Y = y_resampled[train_index], y_resampled[test_index]

        Train_X = [x[0] for x in Train_X]
        Test_X = [x[0] for x in Test_X]

        # Tokenization and padding of sequences
        tok = Tokenizer(num_words=max_words)
        tok.fit_on_texts(Train_X)
        sequences = tok.texts_to_sequences(Train_X)
        sequences_matrix = pad_sequences(sequences, maxlen=max_len)

        # Compile and train the model
        bidirectionalGRU_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
        history = bidirectionalGRU_model.fit(sequences_matrix, Train_Y, batch_size=100, epochs=10, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', min_delta=0.0001)])
        
        # Predict and evaluate
        test_sequences = tok.texts_to_sequences(Test_X)
        test_sequences_matrix = pad_sequences(test_sequences, maxlen=max_len)
        predictions = bidirectionalGRU_model.predict(test_sequences_matrix).round().flatten()
        acc_score.append(accuracy_score(Test_Y, predictions))
        all_predictions.extend(predictions)
        all_actuals.extend(Test_Y)

    avg_acc_score = sum(acc_score) / k
    print('Avg accuracy : {}'.format(avg_acc_score))
    return history, np.array(all_predictions), np.array(all_actuals)

# Train the model and get the history object, predictions, and actual values
history, all_predictions, all_actuals = get_dataset_words_frequency(X_resampled, y_resampled, max_words, max_len)

# Plot training and validation accuracy and loss
def plot_history(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

plot_history(history)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = confusion_matrix(y_true, y_pred)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_proba):
    fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Plot the confusion matrix and ROC curve
plot_confusion_matrix(all_actuals, all_predictions, classes=["Functional", "Non_Functional"])
plot_roc_curve(all_actuals, all_predictions)

# Print classification report
print(classification_report(all_actuals, all_predictions))
# Out:
# Dataset loaded.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Younas\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# NLTK data downloaded.
# C:\Users\Younas\AppData\Local\Temp\ipykernel_6120\4057975267.py:41: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")
# Epoch 1/10
# 11/11 [==============================] - 86s 756ms/step - loss: 0.6741 - accuracy: 0.6154 - val_loss: 0.8655 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 4s 411ms/step - loss: 0.6611 - accuracy: 0.6238 - val_loss: 0.9295 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 5s 65ms/step
# Epoch 1/10
# 11/11 [==============================] - 102s 2s/step - loss: 0.6569 - accuracy: 0.6313 - val_loss: 0.9378 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 6s 540ms/step - loss: 0.6567 - accuracy: 0.6313 - val_loss: 0.9495 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 8s 32ms/step
# Epoch 1/10
# 11/11 [==============================] - 90s 1s/step - loss: 0.6610 - accuracy: 0.6242 - val_loss: 0.9156 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 5s 457ms/step - loss: 0.6511 - accuracy: 0.6242 - val_loss: 0.9584 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 6s 48ms/step
# Epoch 1/10
# 11/11 [==============================] - 37s 636ms/step - loss: 0.6457 - accuracy: 0.6251 - val_loss: 0.9445 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 4s 413ms/step - loss: 0.6341 - accuracy: 0.6251 - val_loss: 0.9506 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 3s 26ms/step
# Epoch 1/10
# 11/11 [==============================] - 29s 601ms/step - loss: 0.6373 - accuracy: 0.6186 - val_loss: 0.9119 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 11/11 [==============================] - 3s 309ms/step - loss: 0.6155 - accuracy: 0.6261 - val_loss: 0.9894 - val_accuracy: 0.0000e+00
# 5/5 [==============================] - 4s 34ms/step
# Epoch 1/10
# 11/11 [==============================] - 30s 475ms/step - loss: 0.6006 - accuracy: 0.6279 - val_loss: 0.8669 - val_accuracy: 0.3258
# Epoch 2/10
# 11/11 [==============================] - 3s 260ms/step - loss: 0.5831 - accuracy: 0.6813 - val_loss: 0.8570 - val_accuracy: 0.4532
# Epoch 3/10
# 11/11 [==============================] - 3s 272ms/step - loss: 0.5560 - accuracy: 0.7451 - val_loss: 0.8344 - val_accuracy: 0.5543
# Epoch 4/10
# 11/11 [==============================] - 3s 268ms/step - loss: 0.5325 - accuracy: 0.7741 - val_loss: 0.8809 - val_accuracy: 0.5131
# 5/5 [==============================] - 2s 22ms/step
# Epoch 1/10
# 11/11 [==============================] - 22s 466ms/step - loss: 0.6068 - accuracy: 0.6570 - val_loss: 0.8798 - val_accuracy: 0.5431
# Epoch 2/10
# 11/11 [==============================] - 3s 258ms/step - loss: 0.5685 - accuracy: 0.7048 - val_loss: 0.8601 - val_accuracy: 0.5506
# Epoch 3/10
# 11/11 [==============================] - 3s 250ms/step - loss: 0.5457 - accuracy: 0.7451 - val_loss: 0.8142 - val_accuracy: 0.5730
# Epoch 4/10
# 11/11 [==============================] - 3s 253ms/step - loss: 0.5137 - accuracy: 0.7629 - val_loss: 0.8271 - val_accuracy: 0.5730
# 5/5 [==============================] - 2s 23ms/step
# Epoch 1/10
# 11/11 [==============================] - 22s 462ms/step - loss: 0.5523 - accuracy: 0.6954 - val_loss: 0.8447 - val_accuracy: 0.5393
# Epoch 2/10
# 11/11 [==============================] - 3s 261ms/step - loss: 0.5177 - accuracy: 0.7404 - val_loss: 0.8232 - val_accuracy: 0.5693
# Epoch 3/10
# 11/11 [==============================] - 3s 250ms/step - loss: 0.4923 - accuracy: 0.7601 - val_loss: 0.7947 - val_accuracy: 0.5993
# Epoch 4/10
# 11/11 [==============================] - 3s 267ms/step - loss: 0.4678 - accuracy: 0.7751 - val_loss: 0.7394 - val_accuracy: 0.6404
# Epoch 5/10
# 11/11 [==============================] - 3s 273ms/step - loss: 0.4443 - accuracy: 0.7948 - val_loss: 0.7837 - val_accuracy: 0.6367
# 5/5 [==============================] - 1s 22ms/step
# Epoch 1/10
# 11/11 [==============================] - 22s 467ms/step - loss: 0.6092 - accuracy: 0.6776 - val_loss: 0.8909 - val_accuracy: 0.5318
# Epoch 2/10
# 11/11 [==============================] - 3s 254ms/step - loss: 0.5543 - accuracy: 0.7151 - val_loss: 0.8597 - val_accuracy: 0.5318
# Epoch 3/10
# 11/11 [==============================] - 3s 252ms/step - loss: 0.5222 - accuracy: 0.7413 - val_loss: 0.8106 - val_accuracy: 0.5506
# Epoch 4/10
# 11/11 [==============================] - 3s 266ms/step - loss: 0.4826 - accuracy: 0.7685 - val_loss: 0.7365 - val_accuracy: 0.6067
# Epoch 5/10
# 11/11 [==============================] - 3s 253ms/step - loss: 0.4557 - accuracy: 0.7929 - val_loss: 0.8195 - val_accuracy: 0.5618
# 5/5 [==============================] - 1s 34ms/step
# Epoch 1/10
# 11/11 [==============================] - 19s 448ms/step - loss: 0.5728 - accuracy: 0.6917 - val_loss: 0.9527 - val_accuracy: 0.4345
# Epoch 2/10
# 11/11 [==============================] - 3s 267ms/step - loss: 0.5333 - accuracy: 0.7263 - val_loss: 0.7191 - val_accuracy: 0.6105
# Epoch 3/10
# 11/11 [==============================] - 3s 254ms/step - loss: 0.4989 - accuracy: 0.7676 - val_loss: 0.8413 - val_accuracy: 0.5281
# 5/5 [==============================] - 2s 23ms/step
# Avg accuracy : 0.6074551061128243
#               precision    recall  f1-score   support
#
#            0       0.57      0.90      0.70       741
#            1       0.76      0.31      0.44       741
#
#     accuracy                           0.61      1482
#    macro avg       0.67      0.61      0.57      1482
# weighted avg       0.67      0.61      0.57      1482
